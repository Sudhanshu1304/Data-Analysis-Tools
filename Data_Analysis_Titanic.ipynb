# %% [markdown]
# #    DATA VISUALIZATION
#
#
#
# In this NoteBook we are going to see ,how to Study give Data through Various Visualization Techniques.
#
# We will be majorly using seaboarn and matplotlib.pyplot .
#
#
# We will be Examining the Titanic Data Set.

# %%
# Importing the libraries 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data=pd.read_csv('D:/User/Desktop/train.csv')

# This is used to see the first 5 rows of the data set
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# This command gives us a basic overlook of our data set

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# From the above information we could see that There are total of 891
#
# rows in total, But Age,Cabin,Embarked have some missing data.

# %% [markdown]
# # DATA PREPROCESSING.....

# %%
# WE WILL FILL THE NIL DATA WITH THE MEAN OF THE AGE DATA

data['Age'].fillna(value=data['Age'].mean(),inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# NOW WE ARE LOOKING AT EMBARKED DATA COUNT

data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# FOR EMBARKED ONLY 2 DATA ARE MESSING SO WE COULD GIVE IT ANY VALUE LET IT BE 'C'

data['Embarked']=data['Embarked'].fillna('C')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# # NAMES
#
#
# Let us deal with the Name Column .We will first create a column with Titels of people .
# Then will count No. of people belonging to a perticular title .Title which occured for more than 10 times will be assined a
# perticular number and others will come under the same number.

# %%
# CREATING THE TITLE COLUMN

a=data['Name'].map(lambda name:name.split(' ')[1]).map(lambda name2:name2.split('.')[0])
a
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Name, Length: 891, dtype: object

# %%
# COUNTING THE OCCURENCE OF EACH TITLE

a.value_counts()
# Out:
# Mr              502
# Miss            179
# Mrs             121
# Master           40
# Dr                7
# Rev               6
# y                 4
# Planke,           3
# Impe,             3
# Mlle              2
# Major             2
# Col               2
# Gordon,           2
# Carlo,            1
# Ms                1
# Don               1
# Shawah,           1
# Cruyssen,         1
# der               1
# Mme               1
# Billiard,         1
# Walle,            1
# Steen,            1
# Capt              1
# Messemaeker,      1
# Mulder,           1
# the               1
# Velde,            1
# Pelsmaeker,       1
# Jonkheer          1
# Melkebeke,        1
# Name: Name, dtype: int64

# %%
d={'Mr':1,'Miss':2,'Mrs':3,'Master':4}
for i in range(len(a)):
    #print(str(a[i]))
    a[i]=d.get(a[i],5)
a
# Out:
# 0      1
# 1      3
# 2      2
# 3      3
# 4      1
#       ..
# 886    5
# 887    2
# 888    2
# 889    1
# 890    1
# Name: Name, Length: 891, dtype: object

# %%
data['Name']=a
data
# Out:
#      PassengerId  Survived  Pclass Name     Sex        Age  SibSp  Parch  \
# 0              1         0       3    1    male  22.000000      1      0
# 1              2         1       1    3  female  38.000000      1      0
# 2              3         1       3    2  female  26.000000      0      0
# 3              4         1       1    3  female  35.000000      1      0
# 4              5         0       3    1    male  35.000000      0      0
# ..           ...       ...     ...  ...     ...        ...    ...    ...
# 886          887         0       2    5    male  27.000000      0      0
# 887          888         1       1    2  female  19.000000      0      0
# 888          889         0       3    2  female  29.699118      1      2
# 889          890         1       1    1    male  26.000000      0      0
# 890          891         0       3    1    male  32.000000      0      0
#
#                Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # TICKETS

# %%
# We cam see there seams to be no significance of the first column in this so we will choose the number columns insted

a=data['Ticket'].map(lambda tic:tic.split(' '))
a.head(20)
# Out:
# 0            [A/5, 21171]
# 1             [PC, 17599]
# 2     [STON/O2., 3101282]
# 3                [113803]
# 4                [373450]
# 5                [330877]
# 6                 [17463]
# 7                [349909]
# 8                [347742]
# 9                [237736]
# 10             [PP, 9549]
# 11               [113783]
# 12           [A/5., 2151]
# 13               [347082]
# 14               [350406]
# 15               [248706]
# 16               [382652]
# 17               [244373]
# 18               [345763]
# 19                 [2649]
# Name: Ticket, dtype: object

# %%
# This code deels gets the number part of the ticket data

a=data['Ticket'].map(lambda num:num.split(' '))
for i in range(len(a)):
    if len(a[i])>1:
        a[i]=a[i][-1]
    else:a[i]=a[0]

data['Ticket']=a
data.head()
# Out:
#    PassengerId  Survived  Pclass Name     Sex   Age  SibSp  Parch   Ticket  \
# 0            1         0       3    1    male  22.0      1      0    21171
# 1            2         1       1    3  female  38.0      1      0    17599
# 2            3         1       3    2  female  26.0      0      0  3101282
# 3            4         1       1    3  female  35.0      1      0    21171
# 4            5         0       3    1    male  35.0      0      0    21171
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %% [markdown]
# # GRAPHICAL ANALYSIS
#
#
#
#
# First we will the cabin data and then Analize the data to find the Relation between the given Data COLUMNS

# %%
# Removing the Cabin and Passengerld Data Columns since they don't look to be usefull for our model at all.

data=data.drop(['PassengerId','Cabin'],axis=1)
data
# Out:
#      Survived  Pclass Name     Sex        Age  SibSp  Parch   Ticket     Fare  \
# 0           0       3    1    male  22.000000      1      0    21171   7.2500
# 1           1       1    3  female  38.000000      1      0    17599  71.2833
# 2           1       3    2  female  26.000000      0      0  3101282   7.9250
# 3           1       1    3  female  35.000000      1      0    21171  53.1000
# 4           0       3    1    male  35.000000      0      0    21171   8.0500
# ..        ...     ...  ...     ...        ...    ...    ...      ...      ...
# 886         0       2    5    male  27.000000      0      0    21171  13.0000
# 887         1       1    2  female  19.000000      0      0    21171  30.0000
# 888         0       3    2  female  29.699118      1      2     6607  23.4500
# 889         1       1    1    male  26.000000      0      0    21171  30.0000
# 890         0       3    1    male  32.000000      0      0    21171   7.7500
#
#     Embarked
# 0          S
# ...

# %% [markdown]
# # Let's see the relation between the Pclass,Sex,Survived
#
#
# Pclass basically representes the class1,class2 and class3 people

# %%
# RELATON BETWEEN Pclass AND SURVIVED

sns.barplot(x='Pclass',y='Survived',data=data)

# %% [markdown]
# FROM THE ABOVE GRAPH WE COULD SEE THAT ABOUT THE MAXIMUM PEOPLE DIED WERE FROM CLASS 3 THEN CLASS 2 THEN CLASS 1.

# %%
# LOOKING AT THE STRENGTS OF MALE AND FEMALE POPULATION

a=data['Sex'].value_counts()
a.plot(kind='bar')
print(a.value_counts())
# Out:
# 314    1
# 577    1
# Name: Sex, dtype: int64

# %%
# SEPRATING THE MALE AND FEMALE DATA

women = data[data['Sex']=='female']
men = data[data['Sex']=='male']
men
# Out:
#      Survived  Pclass Name   Sex        Age  SibSp  Parch  Ticket     Fare  \
# 0           0       3    1  male  22.000000      1      0   21171   7.2500
# 4           0       3    1  male  35.000000      0      0   21171   8.0500
# 5           0       3    1  male  29.699118      0      0   21171   8.4583
# 6           0       1    1  male  54.000000      0      0   21171  51.8625
# 7           0       3    4  male   2.000000      3      1   21171  21.0750
# ..        ...     ...  ...   ...        ...    ...    ...     ...      ...
# 883         0       2    1  male  28.000000      0      0   34068  10.5000
# 884         0       3    1  male  25.000000      0      0  392076   7.0500
# 886         0       2    5  male  27.000000      0      0   21171  13.0000
# 889         1       1    1  male  26.000000      0      0   21171  30.0000
# 890         0       3    1  male  32.000000      0      0   21171   7.7500
#
#     Embarked
# 0          S
# 4          S
# 5          Q
# ...

# %%
# CLASSWISE SIRVIVAL RATE OF MEN

sns.barplot(x='Pclass', y='Survived', data=men)

# %%
# CLASSWISE SIRVIVAL RATE OF WOMEN

sns.barplot(x='Pclass', y='Survived', data=men)

# %%
#Checking class wise population

c1=data[data['Pclass']==1]
c2=data[data['Pclass']==2]
c3=data[data['Pclass']==3]

# %%
print(len(c1))
print(len(c2))
print(len(c3))
# Out:
# 216
# 184
# 491

# %%
#TOTAL NO OF PEOPLE IN CLASS 1,2,3 died 

a=c1[c1['Survived']==0]
b=c2[c2['Survived']==0]
c=c3[c3['Survived']==0]
print(len(a),len(b),len(c))
# Out:
# 80 97 372

# %%
# CALCULATIONS
80/216
# Out:
# 0.37037037037037035

# %% [markdown]
# BASICALLY Almost 55% of the Total population was from CLASS 3 ,20% from CLASS 2, 24% from class 1.
#
# And Almost 75% From class3 Died, 52% from CLASS 2, 37% Died from CLASS 1.

# %%
#THIS CONCLUSION IS SHOWED BY THE BLOW GRAPH

sns.barplot(x='Pclass', y='Survived', data=men)

# %%
grid = sns.FacetGrid(data, col='Pclass',size=4, aspect=1.1)
grid.map(plt.hist, 'Sex', alpha=.5, bins=40)
grid.add_legend();

# %%
WE CAN SEE THAT THE MAXIMUM MALE POPULATION WAS IN CLASS 3

THE MAXIMUM PEOPEAL DIED IN CLASS 3 .

from the above blocks we first saw that 20% of total MEN and 75% of total WOMEN Survived.So basically total no of mens died were more than femals which was less expected naturally .

When we broke down things we saw its reason is that about 60% of over all men and only 45% of total weman were in CLASS 3 .And as we know max no of people died is contributed from CLASS 3 ,Hence the no of male died is greater than women.

So now we know why Total No of Men Died is More than Weman.

# %%
# Reltion between SEX and Servived

sns.barplot(x='Sex',y='Survived',data=data)

# %% [markdown]
# IN THIS ABOVE PLOT WE CAN SEE THAT ABOUT 75% OF THE FEMALE SUVIVED AND ONLY 25% OF THE TOTAL MEN SURVIVED
# WHICH IS NATURALLY UNEXPECTED
#
# SO WE WILL TRY TO FIND THE REASON FOR THIS PROBLEM

# %%
data
# Out:
#      Survived  Pclass Name     Sex        Age  SibSp  Parch   Ticket     Fare  \
# 0           0       3    1    male  22.000000      1      0    21171   7.2500
# 1           1       1    3  female  38.000000      1      0    17599  71.2833
# 2           1       3    2  female  26.000000      0      0  3101282   7.9250
# 3           1       1    3  female  35.000000      1      0    21171  53.1000
# 4           0       3    1    male  35.000000      0      0    21171   8.0500
# ..        ...     ...  ...     ...        ...    ...    ...      ...      ...
# 886         0       2    5    male  27.000000      0      0    21171  13.0000
# 887         1       1    2  female  19.000000      0      0    21171  30.0000
# 888         0       3    2  female  29.699118      1      2     6607  23.4500
# 889         1       1    1    male  26.000000      0      0    21171  30.0000
# 890         0       3    1    male  32.000000      0      0    21171   7.7500
#
#     Embarked
# 0          S
# ...

# %%
sns.barplot(x='Name',y='Survived',data=data)

# %%
grid = sns.FacetGrid(data, row='Pclass',col='Sex' ,size=3, aspect=1.1)
grid.map(plt.hist, 'Name', alpha=.5, bins=40)
grid.add_legend();

# %%
d
# Out:
# {'Mr': 1, 'Miss': 2, 'Mrs': 3, 'Master': 4}

# %%
# EMBARKED DATA
sns.barplot(x='Embarked',y='Survived',data=data)

# %%
grid=sns.FacetGrid(data,row='Pclass',aspect=1.2,size=4)
grid.map(plt.hist,'Embarked',alpha=0.5,bins=40)
grid.add_legend();

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Embarked    891 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
sns.barplot(x='Fare',y='Pclass',data=data)

# %%
data.head(2)
# Out:
#    Survived  Pclass Name     Sex   Age  SibSp  Parch Ticket     Fare Embarked
# 0         0       3    1    male  22.0      1      0  21171   7.2500        S
# 1         1       1    3  female  38.0      1      0  17599  71.2833        C

# %%
data['Sex'].replace(to_replace=['male','female'],value=[0,1],inplace=True)
data['Embarked'].replace(to_replace=['S','C','Q'],value=[1,2,3],inplace=True)
data
# Out:
#      Survived  Pclass Name  Sex        Age  SibSp  Parch   Ticket     Fare  \
# 0           0       3    1    0  22.000000      1      0    21171   7.2500
# 1           1       1    3    1  38.000000      1      0    17599  71.2833
# 2           1       3    2    1  26.000000      0      0  3101282   7.9250
# 3           1       1    3    1  35.000000      1      0    21171  53.1000
# 4           0       3    1    0  35.000000      0      0    21171   8.0500
# ..        ...     ...  ...  ...        ...    ...    ...      ...      ...
# 886         0       2    5    0  27.000000      0      0    21171  13.0000
# 887         1       1    2    1  19.000000      0      0    21171  30.0000
# 888         0       3    2    1  29.699118      1      2     6607  23.4500
# 889         1       1    1    0  26.000000      0      0    21171  30.0000
# 890         0       3    1    0  32.000000      0      0    21171   7.7500
#
#      Embarked
# 0           1
# 1           2
# 2           1
# ...

# %%
data['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
grid=sns.FacetGrid(data,row='Parch',col='Pclass',size=3,aspect=2.0)
grid.map(plt.hist,'SibSp',alpha=0.5,bins=40)
grid.add_legend();

# %% [markdown]
# # IMPORTENT FEATURES
#
#
# Pclass,Sex,Age are the Most importent Features ,
#
# While Name,Embarked SibSp,Parch are comparatively less Significant ,
#
# And Ticket and Fare Should not be concidered

# %% [markdown]
# # MODEL TRANING

# %%
from sklearn.linear_model import LogisticRegression
lgr=LogisticRegression()
X=data.iloc[:,[1,2,3,4,5,6,9]]
Y=data.iloc[:,[0]]
lgr.fit(X,Y)
pr=lgr.predict(X)
from sklearn.metrics import accuracy_score
accuracy_score(Y,pr)
# Out:
# C:\Users\SUDHANSHU\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\SUDHANSHU\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.8125701459034792

# %% [markdown]
# # ACCURACY_SCORE = 81.25 %
